# %%
pip install Pillow
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from PIL import Image

# Kullanıcı inputunu al
user_input = input("1 yazarak görseli gösterin: ")

# Eğer kullanıcı 1 yazarsa
if user_input == "1":
    # Göstermek istediğiniz dosyanın adını belirtin
    filename = "Hsplit.jpg"

    # Dosyayı açın
    img = Image.open(filename)

    # Dosyayı gösterin
    img.show()

# %%
from PIL import Image

# Kullanıcı inputunu al
user_input = input("1 yazarak görseli gösterin: ")

# Eğer kullanıcı 1 yazarsa
if user_input == "1":
    # Göstermek istediğiniz dosyanın adını belirtin
    filename = "Hsplit.jpg"

    # Dosyayı açın
    img = Image.open(filename)

    # Dosyayı kaydedin
    img.save("output.png")

    # Dosyayı tekrar açarak gösterin
    img_output = Image.open("output.png")
    img_output.show()

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.6/7.6 MB 3.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 163.0/163.0 kB 3.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 4.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.4/55.4 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 98.3/98.3 kB 2.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Kullanıcı inputunu al
user_input = input("1 yazarak görseli gösterin: ")

# Eğer kullanıcı 1 yazarsa
if user_input == "1":
    # Göstermek istediğiniz dosyanın adını belirtin
    filename = "Hsplit.jpg"

    # Dosyayı açın
    img = Image.open(filename)

    # Görseli gösterin
    plt.imshow(img)
    plt.show()

# %%
from PIL import Image
from IPython.display import display

# Kullanıcı inputunu al
user_input = input("1 yazarak görseli gösterin: ")

# Eğer kullanıcı 1 yazarsa
if user_input == "1":
    # Göstermek istediğiniz dosyanın adını belirtin
    filename = "Hsplit.jpg"

    # Dosyayı açın
    img = Image.open(filename)

    # Görseli gösterin
    display(img)
print("Seçeneği işaretleyinizzz...")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=351x402>
# Seçeneği işaretleyinizzz...

# %%
class Kisi():
    def init(self, kimlik_no, ad_soyad, dogum_yili, cinsiyet, oncelik_durumu):
        self.kimlik_no = kimlik_no
        self.ad_soyad = ad_soyad
        self.dogum_yili = dogum_yili
        self.cinsiyet = cinsiyet
        self.oncelik_durumu = oncelik_durumu

    def str(self):
        return f"Kimlik No: {self.kimlik_no}\nAd Soyad: {self.ad_soyad}\nDoğum Yılı: {self.dogum_yili}\nCinsiyet: {self.cinsiyet}\nÖncelik Durumu: {self.oncelik_durumu}\n"
    @classmethod
    def kaydet(cls, kisiler, Kisi_Bilgileri):
        with open(Kisi_Bilgileri.txt, 'a') as dosya:
            for kisi in kisiler:
                dosya.write(str(kisi))
                dosya.write('\n')

kisiler = []

while True:
    print("Bilgileri giriniz veya çıkmak için 'q' girin:")
    kimlik_no = input("Kimlik No: ")
    if kimlik_no == 'q':
        break
    ad_soyad = input("Ad Soyad: ")
    dogum_yili = input("Doğum Yılı: ")
    cinsiyet = input("Cinsiyet: ")
    oncelik_durumu = input("Öncelik Durumu(-7 & +65 Yaş/ Engelli/ Şehit-Gazi Yakınlık/ Randevulu/ Yok): ")

kisi = Kisi(kimlik_no, ad_soyad, dogum_yili, cinsiyet, oncelik_durumu)
kisiler.append(kisi)

kisi.kaydet(kisiler, 'Kisi_Bilgileri.txt')
# Out:
# Bilgileri giriniz veya çıkmak için 'q' girin:
# Bilgileri giriniz veya çıkmak için 'q' girin:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 30
#      27     cinsiyet = input("Cinsiyet: ")
#      28     oncelik_durumu = input("Öncelik Durumu(-7 & +65 Yaş/ Engelli/ Şehit-Gazi Yakınlık/ Randevulu/ Yok): ")
# ---> 30 kisi = Kisi(kimlik_no, ad_soyad, dogum_yili, cinsiyet, oncelik_durumu)
#      31 kisiler.append(kisi)
#      33 kisi1.kaydet(kisiler, 'Kisi_Bilgileri.txt')
#
# TypeError: Kisi() takes no arguments

# %%
{"14884157132" : ["Efe Türkan" , 2003,"Erkek","Özel durum yok."]}

# %%
kisi1 =str({"14884157132" : ["Efe Türkan" , 2003,"Erkek","Özel durum yok."]})

# %%
kisi1[2:-2]
# Out:
# "14884157132': ['Efe Türkan', 2003, 'Erkek', 'Özel durum yok.'"

# %%
with open("Kisi_Bilgileri2.txt","w",encoding="utf-8") as file:
        file.writelines(kisi1)

# %%
class Kisi:
    def __init__(self, kimlik_no, ad_soyad, dogum_yili, cinsiyet, oncelik_durumu):
        self.kimlik_no = kimlik_no
        self.ad_soyad = ad_soyad
        self.dogum_yili = dogum_yili
        self.cinsiyet = cinsiyet
        self.oncelik_durumu = oncelik_durumu

    def __str__(self):
        return f"Kimlik No: {self.kimlik_no}\nAd Soyad: {self.ad_soyad}\nDoğum Yılı: {self.dogum_yili}\nCinsiyet: {self.cinsiyet}\nÖncelik Durumu: {self.oncelik_durumu}\n"
    kisi1 = {"14884157132" : ["Efe Türkan" , 2003,"Erkek","Özel durum yok."]}
    with open("Kisi_Bilgileri.txt","a",encoding="utf-8") as file:
        file.write(kisi1 , "\n") 

    @classmethod
    def kaydet(cls, kisiler, dosya_adi):
        with open(dosya_adi, 'r+' , encoding="UTF-8") as dosya:
            for kisi in kisiler:
                dosya.write(str(kisi))
                dosya.write('\n')

kisiler = []

while True:
    print("Bilgileri giriniz veya çıkmak için 'q' girin:")
    kimlik_no = input("Kimlik No: ")
    if kimlik_no == 'q':
        break
    ad_soyad = input("Ad Soyad: ")
    dogum_yili = input("Doğum Yılı: ")
    cinsiyet = input("Cinsiyet: ")
    oncelik_durumu = input("Öncelik Durumu(-7 & +65 Yaş/ Engelli/ Şehit-Gazi Yakınlık/ Randevulu/ Yok): ")
    
    kisi = Kisi(kimlik_no, ad_soyad, dogum_yili, cinsiyet, oncelik_durumu)
    kisiler.append(kisi)

Kisi.kaydet(kisiler, 'Kisi_Bilgileri.txt')
# Out:
# Bilgileri giriniz veya çıkmak için 'q' girin:
# Bilgileri giriniz veya çıkmak için 'q' girin:

# %%
class Kisi:
    @classmethod
    def bul(cls, kimlik_no, dosya_adi):
         with open(dosya_adi, 'r+' , encoding="utf-8") as dosya:
            for i, satir in enumerate(dosya):
                #print(satir , i)
                if kimlik_no in dosya:
                    if i % 6 == 1:  # Ad ve Soyad bilgisi 2. satırdan başlıyor.
                        ad_soyad = satir.strip()
                    elif i % 6 == 0:  # Kimlik No bilgileri 6 şar artan bir algoritmada ilerliyor.
                        if satir.strip() == kimlik_no:
                            print(f"{ad_soyad} Ara yüz yükleniyor. Lütfen Bekleyiniz...")
                            return
                # elif kimlik_no not in dosya:
                    # print("Girdiginiz kimlik numarasına ait kişi bulunamadı. Lütfen kontrol ederek tekrar deneyiniz..!")


Kisi.bul( kimlik_no=input("Kimlik Numaranızı giriniz: "), dosya_adi="Kisi_Bilgileri.txt")

# %%
deneme = {"1488415" : ["Efe Türkan" , 2003,"Erkek","özel durum yok"]}

# %%
kimlik = input()
print(deneme[kimlik][0])
print(deneme[kimlik][1])
print(deneme[kimlik][2])
# Out:
# Efe Türkan
# 2003
# Erkek

# %%
# Dosya adı ve dosya yolu
filename = "kullanicilar.txt"

# Yeni kullanıcı ekleme
def yeni_kullanici():
    kimlik_no = input("Kimlik numarasını girin: ")
    ad = input("Adınızı girin: ")
    soyad = input("Soyadınızı girin: ")
    yas = input("Yaşınızı girin: ")
    engel_durumu = input("Engel durumunuzu girin: ")

    with open(filename, 'a') as f:
        f.write(f"{kimlik_no},{ad},{soyad},{yas},{engel_durumu}\n")

# Kullanıcının bilgilerini al
def kullanici_bilgileri(kimlik_no):
    with open(filename, 'r') as f:
        for satir in f:
            bilgiler = satir.strip().split(',')
            if bilgiler[0] == kimlik_no:
                return bilgiler[1], bilgiler[2], bilgiler[3], bilgiler[4]

    return None

# Kullanıcının bilgilerini yazdır
def kullanici_bilgileri_yazdir():
    kimlik_no = input("Kimlik numaranızı girin: ")
    bilgiler = kullanici_bilgileri(kimlik_no)
    if bilgiler is None:
        print("Kullanıcı bulunamadı")
    else:
        print(f"Adı: {bilgiler[0]} {bilgiler[1]} lütfen bekleyiniz...")

# Ana menü
while True:
    print("\n1 - Yeni kullanıcı ekle")
    print("2 - Kullanıcının bilgilerini yazdır")
    print("3 - Çıkış")
    secim = input("Seçiminizi girin (1/2/3): ")

    if secim == '1':
        yeni_kullanici()
    elif secim == '2':
        kullanici_bilgileri_yazdir()
        break
    elif secim == '3':
        break
    else:
        print("Geçersiz seçim")
# Out:
# 1 - Yeni kullanıcı ekle
# 2 - Kullanıcının bilgilerini yazdır
# 3 - Çıkış
# Adı: Şakircan Akyüz lütfen bekleyiniz...
