# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
class Vehicle:
    def __init__(self,name,speed,mileage):
        self.name = name
        self.speed = speed
        self.mileage = mileage
    def show_info(self):
        print(f"Araç adı:{self.name} Araç Hızı:{self.speed} Mesafe:{self.mileage}")
class Bus(Vehicle):
   def __init__(self):
        self.capacity = 50 
        print(f"Bu otobüsün kapasitesi {self.capacity} kişiliktir.")

otobüs = Bus()
# Out:
# Bu otobüsün kapasitesi 50 kişiliktir.

# %%
class Vehicle:
    def __init__(self,name,speed,mileage):
        self.name = name
        self.speed = speed
        self.mileage = mileage
    def show_info(self):
        print(f"Araç adı:{self.name} Araç Hızı:{self.speed} Mesafe:{self.mileage}")
class Bus(Vehicle):
   def __init__(self, name,speed,mileage,capacity):
        super().__init__(name,speed,mileage) 
        self.capacity = 50 
        print(f"Bu otobüsün kapasitesi {self.capacity} kişiliktir.")

otobüs = Bus("Mercedes-Benz",210,23,50)
# Out:
# Bu otobüsün kapasitesi 50 kişiliktir.

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.
