# %% [markdown]
# # Part 1
# YetGen için bir kahve otomatı yapmak istiyoruz. Bu kahve otomatında aşağıdaki adımları gerçekleştirmesini bekliyoruz. Bu işlemler:
#
# Kahve Ekle
# Fiyat Güncelleme
# Miktarı Değiştirme (ekle/kaldır)
# Otomatı Açma
# Otomatı Kapatma
#
# Sorumuzun bu bölümünde sizlerden kahve otomatını oluşturmanızı ve otomat açma, kapama işlemlerini gerçekleştirmenizi bekliyoruz.

# %%
import time
fiyat = {
    "espresso": 60,
    "americano": 70,
    "latte": 80
}

class otomat():
    def otomat1(self, otomat_durum="kapalı", kahve_listesi=["espresso", "americano", "latte"], miktar="küçük", seker=0):
        self.otomat_durum = otomat_durum
        self.kahve_listesi = kahve_listesi
        self.miktar = miktar
        self.fiyat = fiyat
        self.seker = seker
        # YetNot: Bu bölümde otomat_ac isimli bir fonksiyon oluşturup, ekrana "Otomat Açılıyor" yazdırıp, otomatının durumunu açık hale getirmelisin.
    def otomat_ac(self):
        print("Otomat Açılıyor...")
        time.sleep(1)
        self.otomat_durum = "açık"
        pass

    def otomat_kapat(self):
        if self.otomat_durum == "kapalı":
            print("Önce otomatı açınız.")
        else:
            if (self.otomat_durum == "kapalı"):
                print("Otomat zaten kapalı....")
            else:
                print("Otomat kapanıyor...")
kahve_otomatı = otomat()

print("""
Kahve Otomatı
1. Otomatı aç
2. Otomatı kapat
3. Menüyü yazdır
4. Kahve ekle
5. Kahvenizi seçin
6. Fiyat güncelle
Çıkmak için 'q' ya basın.""")

while True:
    islem = input("işlemi seçiniz:")
    if (islem == "q"):
        print("Afiyet olsun!!!")
        break
    elif (islem == "1"):
        kahve_otomatı.otomat_ac()
    elif (islem == "2"):
        kahve_otomatı.otomat_kapat()
        break
# Out:
# Kahve Otomatı
# 1. Otomatı aç
# 2. Otomatı kapat
# 3. Menüyü yazdır
# 4. Kahve ekle
# 5. Kahvenizi seçin
# 6. Fiyat güncelle
# Çıkmak için 'q' ya basın.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 51
#      49     break
#      50 elif (islem == "2"):
# ---> 51     kahve_otomatı.otomat_kapat()
#      52     break
#
# Cell In[16], line 23, in otomat.otomat_kapat(self)
#      22 def otomat_kapat(self):
# ---> 23     if self.otomat_durum == "kapalı":
#      24         print("Önce otomatı açınız.")
#      25     else:
#
# AttributeError: 'otomat' object has no attribute 'otomat_durum'
