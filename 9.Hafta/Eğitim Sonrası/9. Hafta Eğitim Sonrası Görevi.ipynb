# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
import random
import time 

class Kumanda:
    def __init__(self,tv_durum = "Kapalı",tv_ses=0,kanal_listesi = ["Trt"],kanal="Trt"):
        self.tv_durum = tv_durum
        self.tv_ses = tv_ses
        self.kanal_listesi = kanal_listesi
        self.kanal = kanal
    def tv_ac(self):
        if (self.tv_durum == "Açık"):
            print("Televizyon zaten açık....")
        else:
            print("Televizyon açılıyor....")
            self.tv_durum = "Açık"
    def tv_kapat(self):
        if (self.tv_durum == "Kapalı"):
            print("Televizyon zaten kapalı...")
        else:
            print("Televizyon Kapanıyor....")
            self.tv_durum = "Kapalı"
    def ses_ayari(self):
        while 1:
            ses_cevap = input("Sesi azalt : < \n Seri Artır : > \n Çıkış : çıkış ")
            if ses_cevap == "<":
                if (self.tv_ses !=0):
                    self.tv_ses -=1
                    print("Ses" , self.tv_ses)
                else:
                    print("Ses zaten minimum seviyede.", self.tv_ses)
            elif ses_cevap == ">":
                if (self.tv_ses !=20):
                    self.tv_ses +=1
                    print("Ses" , self.tv_ses)
                else:
                    print("Ses zaten maksimum seviyede.", self.tv_ses)
            else:
                print("Ses menüsünden çıkış yapılıyor \n Güncel Ses :" , self.tv_ses)
                break
    def kanal_ekle(self):
        kanal_ismi = input("Hangi kanalı eklemek istiyorsunuz?")
        print("Kanal ekleniyor...")
        time.sleep(1)
        self.kanal_listesi.append(kanal_ismi)
        print(kanal_ismi, "Kanalı eklendi...")
    def rastgele_kanal(self):
        rastgele_kanal = random.randint(0,len(self.kanal_listesi)-1)
        self.kanal = self.kanal_listesi[rastgele_kanal]
        print("Şu anki Kanal:" , self.kanal)
    def kanal_sayısı(self):
        print(len(self.kanal_listesi))
    def kanal_durumu(self):
        print(f"Tv Durumu : {self.tv_durum} \n Tv Ses : {self.tv_ses} \n Kanal Listesi : {self.kanal_listesi} \n Şu anki Kanal : {self.kanal}")
    
kumanda1 = Kumanda()

print("""
KUMANDA YÖNERGELERİ
1_) Tv Aç
2_) Tv Kapat
3_) Ses Ayarları
4_) Kanal Ekle
5_) Kanal Sayısını Öğrenme
6_) Rastgele Kanala Geçme
7_) Televizyon Bilgileri
Çıkmak için "q" tuşuna basınız.
""")

while 1:
    islem = input("İşleminizi seçiniz: ")
    if islem == "q":
        print("Program Sonlandırılıyor...")
        time.sleep(0.75)
        print("Program sonlandı.")
        break
    elif islem == "1":
        kumanda1.tv_ac()
    elif islem =="2":
        kumanda1.tv_kapat()
    elif islem == "3":
        kumanda1.ses_ayari()
    elif islem =="4":
        kumanda1.kanal_ekle()
    elif islem=="5":
        kumanda1.kanal_sayısı()
    elif islem=="6":
        kumanda1.rastgele_kanal()
    elif islem=="7":
        kumanda1.kanal_durumu()
    else:
        print("Geçersiz İşlem!!!!")
# Out:
# KUMANDA YÖNERGELERİ
# 1_) Tv Aç
# 2_) Tv Kapat
# 3_) Ses Ayarları
# 4_) Kanal Ekle
# 5_) Kanal Sayısını Öğrenme
# 6_) Rastgele Kanala Geçme
# 7_) Televizyon Bilgileri
# Çıkmak için "q" tuşuna basınız.
#
# Televizyon açılıyor....
# Kanal ekleniyor...
# Trt Spor Kanalı eklendi...
# 2
# 2
# Şu anki Kanal: Trt Spor
# Şu anki Kanal: Trt
# Şu anki Kanal: Trt
# Tv Durumu : Açık
#  Tv Ses : 0
#  Kanal Listesi : ['Trt', 'Trt Spor']
#  Şu anki Kanal : Trt
# Program Sonlandırılıyor...
# Program sonlandı.
