# %%
def fiyat_guncelleme(self):

if self.otomat_durum == "kapalj|":
Peet Gn ete S EVs Corl) a)

else:
giincel_kahve = PR Tea @ie SAVE Cee) giincellemek istediginiz kahveyi girin: ")
giincel_fiyat = int(input("Ne kadar fiyat eklenecek ? : "))
fiyat.get(giincel_kahve)[0] += giincel_fiyat
fiyat.get(giincel_kahve)[1] += giincel_fiyat
fiyat.get(giincel_kahve) [2] += giincel_fiyat

# %% [markdown]
# # Part 1
# YetGen için bir kahve otomatı yapmak istiyoruz. Bu kahve otomatında aşağıdaki adımları gerçekleştirmesini bekliyoruz. Bu işlemler:
#
# Kahve Ekle
# Fiyat Güncelleme
# Miktarı Değiştirme (ekle/kaldır)
# Otomatı Açma
# Otomatı Kapatma
#
# Sorumuzun bu bölümünde sizlerden kahve otomatını oluşturmanızı ve otomat açma, kapama işlemlerini gerçekleştirmenizi bekliyoruz.

# %%
fiyat = {"espresso": [20, 23, 27],"americano": [25, 27, 30],"latte": [30, 32, 35]}
class otomat():
    def __init__(self, otomat_durum="kapalı", kahve_listesi=["espresso", "americano", "latte"], miktar="küçük", seker=0):
        self.otomat_durum = otomat_durum
        self.kahve_listesi = kahve_listesi
        self.miktar = miktar
        self.fiyat = fiyat
        
# YetNot: Bu bölümde otomat_ac isimli bir fonksiyon oluşturup, ekrana "Otomat Açılıyor" yazdırıp, otomatının durumunu açık hale getirmelisin.
    def otomat_ac(self):
        if (self.otomat_durum == "kapalı"):
            print("Otomat açılıyor....")
            self.otomat_durum = "açık"
        else:
            print("Otomat zaten açık.")
    def otomat_kapat(self):
        if (self.otomat_durum == "kapalı"):
                print("Otomat zaten kapalı....")
        else:
            print("Otomat kapanıyor...")
            self.otomat_durum = "kapalı"

otomat = otomat()
print("""
Kahve Otomatı
1. Otomatı aç
2. Otomatı kapat
3. Menüyü yazdır
4. Kahve ekle
5. Kahvenizi seçin
6. Fiyat güncelle
Çıkmak için 'q' ya basın.""")

while True:
    islem = input("işlemi seçiniz:")
    if (islem == "q"):
        print("Afiyet olsun!!!")
        break
    elif (islem == "1"):
        otomat.otomat_ac()
    elif (islem == "2"):
        otomat.otomat_kapat()
# Out:
# Kahve Otomatı
# 1. Otomatı aç
# 2. Otomatı kapat
# 3. Menüyü yazdır
# 4. Kahve ekle
# 5. Kahvenizi seçin
# 6. Fiyat güncelle
# Çıkmak için 'q' ya basın.
# Otomat açılıyor....
# Otomat zaten açık.
# Otomat kapanıyor...
# Afiyet olsun!!!
